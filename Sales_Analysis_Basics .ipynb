# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sna

#matplotlib inline

# %%
mock_sales_df = pd.read_excel('Mock Actual Sales.xlsx')

# %%
mock_sales_df.head()
# Out:
#      Data  Fiscal Year  Month Number Sales Rep    Customer    Item Category  \
# 0  Actual         2020             9     David  Customer B  Chairs    Metal
# 1  Actual         2020             9     David  Customer B  Chairs    Metal
# 2  Actual         2020             9     David  Customer B  Chairs    Metal
# 3  Actual         2020             9     David  Customer B  Chairs    Metal
# 4  Actual         2020             9     David  Customer B  Chairs    Metal
#
#    Quantity  Gross Sales   Returns  ...     Trade  Fines   Net Sales     COGS  \
# 0    321664    3859968.0  33001.96  ...  93990.50  64.84  3722140.34  3216640
# 1    118368    1420416.0  10581.88  ...   6690.27  80.94  1397906.94  1183680
# 2     62464     749568.0   4384.84  ...   2772.26  12.82   735261.59   624640
# 3     19818     237816.0   3359.08  ...   9428.28   6.61   223921.30   198180
# 4      3283      39396.0   1796.15  ...   9935.60   5.25    26783.83    32830
#
# ...

# %%
mock_sales_df.describe()
# Out:
#        Fiscal Year  Month Number       Quantity   Gross Sales       Returns  \
# count        324.0         324.0     324.000000  3.240000e+02    324.000000
# mean        2020.0           9.0    6250.574074  1.823571e+05    650.855309
# std            0.0           0.0   27567.022664  1.032338e+06   2476.811305
# min         2020.0           9.0      -5.000000 -2.600000e+02      0.000000
# 25%         2020.0           9.0      35.000000  2.140000e+02      4.310000
# 50%         2020.0           9.0     199.500000  2.114400e+03     34.535000
# 75%         2020.0           9.0    1253.500000  2.542900e+04    323.137500
# max         2020.0           9.0  321664.000000  1.224038e+07  33001.960000
#
#                Cash         Trade        Fines     Net Sales          COGS  \
# count    324.000000    324.000000   324.000000  3.240000e+02  3.240000e+02
# mean     396.708704   5000.456265   -39.092191  1.763482e+05  1.432286e+05
# ...

# %%
pd.value_counts(mock_sales_df['Customer']).plot.bar()

plt.title = '# Customer Purchases'

# %%
mock_sales_df.groupby(['Customer', 'Category', 'Item']).mean()
# Out:
#                              Fiscal Year  Month Number      Quantity  \
# Customer   Category Item
# Customer A Metal    Stools        2020.0           9.0  21033.000000
#            Plastic  Pots          2020.0           9.0  29568.000000
#                     Stands        2020.0           9.0  13437.500000
# Customer B Metal    Boxes         2020.0           9.0     13.000000
#                     Chairs        2020.0           9.0  53559.500000
#                     Poles         2020.0           9.0   2454.444444
#                     Stools        2020.0           9.0  14266.500000
#                     Tables        2020.0           9.0  58194.250000
#            Plastic  Stands        2020.0           9.0  28902.750000
# Customer C Metal    Boxes         2020.0           9.0    250.800000
#                     Chairs        2020.0           9.0    219.206897
#                     Poles         2020.0           9.0   2009.307692
# ...

# %%
mock_sales_df.plot()

# %%
mock_sales_df['Gross Sales'].plot()

# %%
mock_sales_df.index
# Out:
# RangeIndex(start=0, stop=324, step=1)

# %%
##This code should join actual sales and budget sales

#Budget_Actual_Comp = mock_sales_df.join(budget_sales_df)

# %%
mock_sales_df['Quantity'].plot()
